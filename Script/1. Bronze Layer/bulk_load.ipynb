# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
from supabase_direct_connection import conn

# %%
with open("../../datasets/source_crm/cust_info.csv") as f:
    print(f.readline())
    print(f.readline())
# Out:
# cst_id,cst_key,cst_firstname,cst_lastname,cst_marital_status,cst_gndr,cst_create_date
#
# 11000,AW00011000, Jon,Yang ,M,M,2025-10-06

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.crm_cust_info
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_crm/cust_info.csv", "rb") as f:
            copy.write(f.read())

conn.commit()

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.crm_prd_info
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_crm/prd_info.csv", "rb") as f:
            copy.write(f.read())

conn.commit()

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.crm_sales_details
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_crm/sales_details.csv", "rb") as f:
            copy.write(f.read())

conn.commit()

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.erp_cust_az12
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_erp/CUST_AZ12.csv", "rb") as f:
            copy.write(f.read())

conn.commit()

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.erp_loc_a101
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_erp/LOC_A101.csv", "rb") as f:
            copy.write(f.read())

conn.commit()

# %%
with conn.cursor() as cur:
    with cur.copy("""
        COPY bronze.erp_px_cat_g1v2
        FROM STDIN
        WITH (FORMAT CSV, HEADER TRUE)
    """) as copy:

        with open("../../datasets/source_erp/PX_CAT_G1V2.csv", "rb") as f:
            copy.write(f.read())

conn.commit()
