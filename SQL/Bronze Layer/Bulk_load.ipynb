# %%
import psycopg2
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import re
from urllib.parse import quote

conn_str = os.getenv("SUPABASE_DATABASE_URL")
print(conn_str)
if conn_str is None:
	raise ValueError("SUPABASE_DATABASE_URL is not set in the environment")

# percent-encode the password portion to avoid issues with characters like '+'
def _encode_password_in_dsn(dsn: str) -> str:
	return re.sub(
		r'://([^:/]+):([^@]+)@',
		lambda m: f'://{m.group(1)}:{quote(m.group(2), safe="")}@',
		dsn,
	)

safe_conn_str = _encode_password_in_dsn(conn_str)
conn = psycopg2.connect(safe_conn_str, sslmode="require")
cur = conn.cursor()
# Out:
# postgresql://postgres:Ezioauditore+1@db.afxybewlldnqnmerwwxu.supabase.co:5432/postgres
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 3
#       1 conn_str = os.getenv("SUPABASE_DATABASE_URL")
#       2 print(conn_str)
# ----> 3 conn = psycopg2.connect(conn_str)
#       4 cur = conn.cursor()
#
# File d:\Study\SQL portfolio Project\.venv\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# OperationalError: could not translate host name "db.afxybewlldnqnmerwwxu.supabase.co" to address: Name or service not known
